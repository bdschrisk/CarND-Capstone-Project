# %% [markdown]
# # Traffic Light Classifier
# **In this notebook, a deep learning approach is used for the purposes of detecting traffic lights and their corresponding state representation (i.e. Red, Green, Yellow).**

# %%
# Dependencies
# Load pickled data
import pickle
import os
import numpy as np
import glob
import matplotlib.pyplot as plt

from math import *

# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# *Define the training and test paths...*

# %%
import model.modelconfig as config

# Define training data paths
training_path = "./data/train/images"
test_path = "./data/test/images"

model_path = "./model/densenet-19/"

if not os.path.exists(model_path):
    os.mkdir(model_path)

# %%
# Extract number of samples

def get_samples(path, patterns = ("*.png", "*.jpg")):
    paths = []
    for key in list(config.labels.keys()):
        dir = os.path.join(path, key)
        for pattern in patterns:
            paths += glob.glob(os.path.join(dir, pattern))
    return paths

train_samples = get_samples(training_path)
test_samples = get_samples(test_path)

print("Number of training samples: {}".format(len(train_samples)))
print("Number of test samples: {}".format(len(test_samples)))
# Out:
# Number of training samples: 38868
# Number of test samples: 23135

# %%
# Uncomment to disable GPU acceleration
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
import keras;
import tensorflow as tf
import keras.backend as K

# Check keras and tensorflow versions
print("Keras version: {}".format(keras.__version__))
print("TensorFlow version: {}".format(tf.__version__))
print("Channels: {}".format(K.image_data_format()))

# Check for a GPU
if not tf.test.gpu_device_name():
    print('No GPU found. Using CPU...')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# Using TensorFlow backend.
# Keras version: 2.0.8
# TensorFlow version: 1.0.0
# Channels: channels_last
# Default GPU Device: /gpu:0

# %% [markdown]
# ### DenseNet model

# %%
class_labels = list(set(config.labels.values()))
print("Class labels: \n{}".format(class_labels))
# Out:
# Class labels:
# [0, 1, 2, 12]

# %%
# Model params
output_size = len(class_labels)
image_size = (None, None, 3)

depth = 19 #40
dense_blocks = 3 #3
growth_rate = 6 #12
filters = 16

dropout = 0.2
weight_decay = 1e-4

# Build model
from model.DenseNet import DenseNet

densenet = DenseNet(output_size, image_size, depth, dense_blocks, growth_rate, 
                 filters, dropout_rate=dropout, weight_decay=weight_decay)
model = densenet.model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Define Optimiser for Training

# %%
# Optimiser params
optimiser = "Adam"
loss = "categorical_crossentropy"
metrics = ["categorical_accuracy", "top_k_categorical_accuracy"]

# Compile model
model.compile(optimiser, loss, metrics=metrics, loss_weights=None, sample_weight_mode=None)

print("\n## Model ##")
print(model.summary())
# Out:
# ## Model ##
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# normalizer_1 (Normalizer)        (None, None, None, 3) 0           input_1[0][0]
# ____________________________________________________________________________________________________
# initial_conv2D (Conv2D)          (None, None, None, 16 432         normalizer_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, None, None, 16 64          initial_conv2D[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, None, None, 16 0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, None, None, 6) 864         activation_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, None, None, 6) 0           conv2d_1[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, None, None, 22 0           initial_conv2D[0][0]
#                                                                    dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, None, None, 22 88          concatenate_1[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, None, None, 22 0           batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, None, None, 6) 1188        activation_2[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, None, None, 6) 0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, None, None, 28 0           initial_conv2D[0][0]
#                                                                    dropout_1[0][0]
#                                                                    dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, None, None, 28 112         concatenate_2[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, None, None, 28 0           batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, None, None, 6) 1512        activation_3[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, None, None, 6) 0           conv2d_3[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, None, None, 34 0           initial_conv2D[0][0]
#                                                                    dropout_1[0][0]
#                                                                    dropout_2[0][0]
#                                                                    dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, None, None, 34 136         concatenate_3[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, None, None, 34 0           batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, None, None, 6) 1836        activation_4[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, None, None, 6) 0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, None, None, 40 0           initial_conv2D[0][0]
#                                                                    dropout_1[0][0]
#                                                                    dropout_2[0][0]
#                                                                    dropout_3[0][0]
#                                                                    dropout_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, None, None, 40 160         concatenate_4[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, None, None, 40 0           batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, None, None, 6) 2160        activation_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, None, None, 6) 0           conv2d_5[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, None, None, 46 0           initial_conv2D[0][0]
#                                                                    dropout_1[0][0]
#                                                                    dropout_2[0][0]
#                                                                    dropout_3[0][0]
#                                                                    dropout_4[0][0]
#                                                                    dropout_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, None, None, 46 184         concatenate_5[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, None, None, 46 0           batch_normalization_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, None, None, 46 2116        activation_6[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, None, None, 46 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_1 (AveragePool (None, None, None, 46 0           dropout_6[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNorm (None, None, None, 46 184         average_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, None, None, 46 0           batch_normalization_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, None, None, 6) 2484        activation_7[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, None, None, 6) 0           conv2d_7[0][0]
# ____________________________________________________________________________________________________
# concatenate_6 (Concatenate)      (None, None, None, 52 0           average_pooling2d_1[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNorm (None, None, None, 52 208         concatenate_6[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, None, None, 52 0           batch_normalization_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, None, None, 6) 2808        activation_8[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, None, None, 6) 0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# concatenate_7 (Concatenate)      (None, None, None, 58 0           average_pooling2d_1[0][0]
#                                                                    dropout_7[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, None, None, 58 232         concatenate_7[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, None, None, 58 0           batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, None, None, 6) 3132        activation_9[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, None, None, 6) 0           conv2d_9[0][0]
# ____________________________________________________________________________________________________
# concatenate_8 (Concatenate)      (None, None, None, 64 0           average_pooling2d_1[0][0]
#                                                                    dropout_7[0][0]
#                                                                    dropout_8[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None, None, None, 64 256         concatenate_8[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, None, None, 64 0           batch_normalization_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, None, None, 6) 3456        activation_10[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, None, None, 6) 0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# concatenate_9 (Concatenate)      (None, None, None, 70 0           average_pooling2d_1[0][0]
#                                                                    dropout_7[0][0]
#                                                                    dropout_8[0][0]
#                                                                    dropout_9[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11 (BatchNor (None, None, None, 70 280         concatenate_9[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, None, None, 70 0           batch_normalization_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, None, None, 6) 3780        activation_11[0][0]
# ____________________________________________________________________________________________________
# dropout_11 (Dropout)             (None, None, None, 6) 0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_10 (Concatenate)     (None, None, None, 76 0           average_pooling2d_1[0][0]
#                                                                    dropout_7[0][0]
#                                                                    dropout_8[0][0]
#                                                                    dropout_9[0][0]
#                                                                    dropout_10[0][0]
#                                                                    dropout_11[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_12 (BatchNor (None, None, None, 76 304         concatenate_10[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, None, None, 76 0           batch_normalization_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, None, None, 76 5776        activation_12[0][0]
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)             (None, None, None, 76 0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_2 (AveragePool (None, None, None, 76 0           dropout_12[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_13 (BatchNor (None, None, None, 76 304         average_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, None, None, 76 0           batch_normalization_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, None, None, 6) 4104        activation_13[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, None, None, 6) 0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_11 (Concatenate)     (None, None, None, 82 0           average_pooling2d_2[0][0]
#                                                                    dropout_13[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_14 (BatchNor (None, None, None, 82 328         concatenate_11[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, None, None, 82 0           batch_normalization_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, None, None, 6) 4428        activation_14[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, None, None, 6) 0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_12 (Concatenate)     (None, None, None, 88 0           average_pooling2d_2[0][0]
#                                                                    dropout_13[0][0]
#                                                                    dropout_14[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_15 (BatchNor (None, None, None, 88 352         concatenate_12[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, None, None, 88 0           batch_normalization_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, None, None, 6) 4752        activation_15[0][0]
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)             (None, None, None, 6) 0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# concatenate_13 (Concatenate)     (None, None, None, 94 0           average_pooling2d_2[0][0]
#                                                                    dropout_13[0][0]
#                                                                    dropout_14[0][0]
#                                                                    dropout_15[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_16 (BatchNor (None, None, None, 94 376         concatenate_13[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, None, None, 94 0           batch_normalization_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, None, None, 6) 5076        activation_16[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)             (None, None, None, 6) 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_14 (Concatenate)     (None, None, None, 10 0           average_pooling2d_2[0][0]
#                                                                    dropout_13[0][0]
#                                                                    dropout_14[0][0]
#                                                                    dropout_15[0][0]
#                                                                    dropout_16[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_17 (BatchNor (None, None, None, 10 400         concatenate_14[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, None, None, 10 0           batch_normalization_17[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, None, None, 6) 5400        activation_17[0][0]
# ____________________________________________________________________________________________________
# dropout_17 (Dropout)             (None, None, None, 6) 0           conv2d_17[0][0]
# ____________________________________________________________________________________________________
# concatenate_15 (Concatenate)     (None, None, None, 10 0           average_pooling2d_2[0][0]
#                                                                    dropout_13[0][0]
#                                                                    dropout_14[0][0]
#                                                                    dropout_15[0][0]
#                                                                    dropout_16[0][0]
#                                                                    dropout_17[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_18 (BatchNor (None, None, None, 10 424         concatenate_15[0][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, None, None, 10 0           batch_normalization_18[0][0]
# ____________________________________________________________________________________________________
# global_average_pooling2d_1 (Glob (None, 106)           0           activation_18[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 4)             428         global_average_pooling2d_1[0][0]
# ====================================================================================================
# Total params: 60,124
# Trainable params: 57,928
# Non-trainable params: 2,196
# ____________________________________________________________________________________________________
# None

# %%
# Train on Bosch dataset
### Training parameters ###
noise = 0.2
batch_size = 32
max_epochs = 40

epoch_train_samples = int(floor(len(train_samples) / batch_size))
epoch_test_samples = int(floor(len(test_samples) / batch_size))

print("Steps per epoch (train): {}".format(epoch_train_samples))
print("Steps per epoch (test): {}".format(epoch_test_samples))
# Out:
# Steps per epoch (train): 1214
# Steps per epoch (test): 722

# %% [markdown]
# ### Training

# %% [markdown]
# *Define image data generators and create noise on training set.*

# %%
import data.helpers.generator as g

print("\nInitializing generators...")

# compile and train the model using the generator function
train_generator = g.generator(training_path, config.labels, batch_size = batch_size, noise = noise)
validation_generator = g.generator(test_path, config.labels, batch_size = batch_size, noise = 0)

print(" - Done.\n")
# Out:
# Initializing generators...
#  - Done.

# %% [markdown]
# *Define callbacks for use during training.*

# %%
### Train ###
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

# setup callbacks, save every checkpoint, check for overfitting and reduce learning rate as required
callbacks = [
    CSVLogger("./model/training-loss.csv", separator=',', append = True),
    #EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience = 10),
    ModelCheckpoint(filepath = config.checkpoint_pattern.replace("*","{epoch:02d}-{val_loss:.2f}"), monitor='val_loss', save_best_only=False, save_weights_only=True, verbose=0),
]

# %% [markdown]
# #### Learning

# %%
print("\nTraining...")

epoch = 0
# Train the model using the supplied generator
history = model.fit_generator(train_generator, steps_per_epoch = epoch_train_samples, 
                              validation_data = validation_generator, validation_steps = epoch_test_samples,
                              epochs = max_epochs, callbacks = callbacks, initial_epoch = epoch)
# Out:
# Training...
# Epoch 1/40
# 1214/1214 [==============================] - 1207s - loss: 0.5373 - categorical_accuracy: 0.8648 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6950 - val_categorical_accuracy: 0.8006 - val_top_k_categorical_accuracy: 1.0000
# Epoch 2/40
# 1214/1214 [==============================] - 856s - loss: 0.3209 - categorical_accuracy: 0.9429 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9158 - val_categorical_accuracy: 0.7505 - val_top_k_categorical_accuracy: 1.0000
# Epoch 3/40
# 1214/1214 [==============================] - 827s - loss: 0.2770 - categorical_accuracy: 0.9519 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0690 - val_categorical_accuracy: 0.7183 - val_top_k_categorical_accuracy: 1.0000
# Epoch 4/40
# 1214/1214 [==============================] - 802s - loss: 0.2467 - categorical_accuracy: 0.9582 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9296 - val_categorical_accuracy: 0.7514 - val_top_k_categorical_accuracy: 1.0000
# Epoch 5/40
# 1214/1214 [==============================] - 798s - loss: 0.2238 - categorical_accuracy: 0.9626 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0388 - val_categorical_accuracy: 0.7616 - val_top_k_categorical_accuracy: 1.0000
# Epoch 6/40
# 1214/1214 [==============================] - 780s - loss: 0.2158 - categorical_accuracy: 0.9633 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7086 - val_categorical_accuracy: 0.7683 - val_top_k_categorical_accuracy: 1.0000
# Epoch 7/40
# 1214/1214 [==============================] - 765s - loss: 0.2014 - categorical_accuracy: 0.9661 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9241 - val_categorical_accuracy: 0.7548 - val_top_k_categorical_accuracy: 1.0000
# Epoch 8/40
# 1214/1214 [==============================] - 771s - loss: 0.1975 - categorical_accuracy: 0.9664 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0674 - val_categorical_accuracy: 0.7428 - val_top_k_categorical_accuracy: 1.0000
# Epoch 9/40
# 1214/1214 [==============================] - 790s - loss: 0.1889 - categorical_accuracy: 0.9674 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6735 - val_categorical_accuracy: 0.7747 - val_top_k_categorical_accuracy: 1.0000
# Epoch 10/40
# 1214/1214 [==============================] - 770s - loss: 0.1817 - categorical_accuracy: 0.9684 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6400 - val_categorical_accuracy: 0.7821 - val_top_k_categorical_accuracy: 1.0000
# Epoch 11/40
# 1214/1214 [==============================] - 764s - loss: 0.1750 - categorical_accuracy: 0.9702 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6959 - val_categorical_accuracy: 0.7599 - val_top_k_categorical_accuracy: 1.0000
# Epoch 12/40
# 1214/1214 [==============================] - 767s - loss: 0.1667 - categorical_accuracy: 0.9719 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6808 - val_categorical_accuracy: 0.7832 - val_top_k_categorical_accuracy: 1.0000
# Epoch 13/40
# 1214/1214 [==============================] - 763s - loss: 0.1680 - categorical_accuracy: 0.9711 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6386 - val_categorical_accuracy: 0.7847 - val_top_k_categorical_accuracy: 1.0000
# Epoch 14/40
# 1214/1214 [==============================] - 757s - loss: 0.1634 - categorical_accuracy: 0.9719 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8057 - val_categorical_accuracy: 0.7479 - val_top_k_categorical_accuracy: 1.0000
# Epoch 15/40
# 1214/1214 [==============================] - 758s - loss: 0.1533 - categorical_accuracy: 0.9744 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6963 - val_categorical_accuracy: 0.7775 - val_top_k_categorical_accuracy: 1.0000
# Epoch 16/40
# 1214/1214 [==============================] - 760s - loss: 0.1562 - categorical_accuracy: 0.9733 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6221 - val_categorical_accuracy: 0.7976 - val_top_k_categorical_accuracy: 1.0000
# Epoch 17/40
# 1214/1214 [==============================] - 764s - loss: 0.1463 - categorical_accuracy: 0.9755 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8348 - val_categorical_accuracy: 0.7919 - val_top_k_categorical_accuracy: 1.0000
# Epoch 18/40
# 1214/1214 [==============================] - 752s - loss: 0.1517 - categorical_accuracy: 0.9744 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7398 - val_categorical_accuracy: 0.7864 - val_top_k_categorical_accuracy: 1.0000
# Epoch 19/40
# 1214/1214 [==============================] - 759s - loss: 0.1440 - categorical_accuracy: 0.9759 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7100 - val_categorical_accuracy: 0.7669 - val_top_k_categorical_accuracy: 1.0000
# Epoch 20/40
# 1214/1214 [==============================] - 753s - loss: 0.1483 - categorical_accuracy: 0.9753 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7110 - val_categorical_accuracy: 0.7894 - val_top_k_categorical_accuracy: 1.0000
# Epoch 21/40
# 1214/1214 [==============================] - 756s - loss: 0.1407 - categorical_accuracy: 0.9766 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6751 - val_categorical_accuracy: 0.7870 - val_top_k_categorical_accuracy: 1.0000
# Epoch 22/40
# 1214/1214 [==============================] - 751s - loss: 0.1398 - categorical_accuracy: 0.9767 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6685 - val_categorical_accuracy: 0.7930 - val_top_k_categorical_accuracy: 1.0000
# Epoch 23/40
# 1214/1214 [==============================] - 749s - loss: 0.1390 - categorical_accuracy: 0.9768 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0221 - val_categorical_accuracy: 0.7508 - val_top_k_categorical_accuracy: 1.0000
# Epoch 24/40
# 1214/1214 [==============================] - 752s - loss: 0.1360 - categorical_accuracy: 0.9772 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6843 - val_categorical_accuracy: 0.7853 - val_top_k_categorical_accuracy: 1.0000
# Epoch 25/40
# 1214/1214 [==============================] - 745s - loss: 0.1308 - categorical_accuracy: 0.9785 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.5187 - val_categorical_accuracy: 0.7169 - val_top_k_categorical_accuracy: 1.0000
# Epoch 26/40
# 1214/1214 [==============================] - 748s - loss: 0.1324 - categorical_accuracy: 0.9784 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.2624 - val_categorical_accuracy: 0.7637 - val_top_k_categorical_accuracy: 1.0000
# Epoch 27/40
# 1214/1214 [==============================] - 748s - loss: 0.1327 - categorical_accuracy: 0.9787 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.5300 - val_categorical_accuracy: 0.8278 - val_top_k_categorical_accuracy: 1.0000
# Epoch 28/40
# 1214/1214 [==============================] - 756s - loss: 0.1285 - categorical_accuracy: 0.9787 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6275 - val_categorical_accuracy: 0.7906 - val_top_k_categorical_accuracy: 1.0000
# Epoch 29/40
# 1214/1214 [==============================] - 741s - loss: 0.1254 - categorical_accuracy: 0.9794 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6891 - val_categorical_accuracy: 0.8010 - val_top_k_categorical_accuracy: 1.0000
# Epoch 30/40
# 1214/1214 [==============================] - 754s - loss: 0.1257 - categorical_accuracy: 0.9792 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.5278 - val_categorical_accuracy: 0.8402 - val_top_k_categorical_accuracy: 1.0000
# Epoch 31/40
# 1214/1214 [==============================] - 753s - loss: 0.1252 - categorical_accuracy: 0.9795 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4735 - val_categorical_accuracy: 0.8436 - val_top_k_categorical_accuracy: 1.0000
# Epoch 32/40
# 1214/1214 [==============================] - 749s - loss: 0.1238 - categorical_accuracy: 0.9803 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7599 - val_categorical_accuracy: 0.8117 - val_top_k_categorical_accuracy: 1.0000
# Epoch 33/40
# 1214/1214 [==============================] - 758s - loss: 0.1208 - categorical_accuracy: 0.9804 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.8297 - val_categorical_accuracy: 0.3950 - val_top_k_categorical_accuracy: 1.0000
# Epoch 34/40
# 1214/1214 [==============================] - 751s - loss: 0.1194 - categorical_accuracy: 0.9813 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7772 - val_categorical_accuracy: 0.8076 - val_top_k_categorical_accuracy: 1.0000
# Epoch 35/40
# 1214/1214 [==============================] - 744s - loss: 0.1198 - categorical_accuracy: 0.9808 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.5912 - val_categorical_accuracy: 0.8215 - val_top_k_categorical_accuracy: 1.0000
# Epoch 36/40
# 1214/1214 [==============================] - 750s - loss: 0.1196 - categorical_accuracy: 0.9813 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7241 - val_categorical_accuracy: 0.8014 - val_top_k_categorical_accuracy: 1.0000
# Epoch 37/40
# 1214/1214 [==============================] - 746s - loss: 0.1173 - categorical_accuracy: 0.9818 - top_k_categorical_accuracy: 1.0000 - val_loss: 3.6483 - val_categorical_accuracy: 0.7203 - val_top_k_categorical_accuracy: 1.0000
# Epoch 38/40
# 1214/1214 [==============================] - 747s - loss: 0.1204 - categorical_accuracy: 0.9807 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8675 - val_categorical_accuracy: 0.7853 - val_top_k_categorical_accuracy: 1.0000
# Epoch 39/40
# 1214/1214 [==============================] - 746s - loss: 0.1196 - categorical_accuracy: 0.9823 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.5042 - val_categorical_accuracy: 0.8156 - val_top_k_categorical_accuracy: 1.0000
# Epoch 40/40
# 1214/1214 [==============================] - 744s - loss: 0.1158 - categorical_accuracy: 0.9824 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6588 - val_categorical_accuracy: 0.8165 - val_top_k_categorical_accuracy: 1.0000

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_top_k_categorical_accuracy', 'val_categorical_accuracy', 'loss', 'top_k_categorical_accuracy', 'categorical_accuracy', 'val_loss'])

# %%
# TODO plot history
#plt.figure(1)
# summarize history for accuracy
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
valid_path = "./data/valid/images"

# %%
model.load_weights(model_path + "checkpoint-30-0.47.h5")

# %%
from mpl_toolkits.axes_grid1 import ImageGrid
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg

images = []
labels = []
labelnames = []

for dir in os.listdir(valid_path):
    sub_path = os.path.join(valid_path, dir)
    if (os.path.isdir(sub_path) and dir in config.labels):
        for img_name in os.listdir(sub_path):
            img_path = os.path.join(sub_path, img_name)
            images.append(img_path)
            labels.append(config.labels[dir])
            labelnames.append(dir)

num_rows = 6
num_cols = 4

fig = plt.figure(figsize=(18, 16))  # width, height in inches

k = 1

for i in range(len(labels)):
    image = mpimg.imread(images[i])
    label = labels[i]
    name = labelnames[i]
    
    image = np.asarray(image)
    
    pred = model.predict(image[None, :, :, 0:3], batch_size=1)[0]
    
    pred_idx = np.argmax(pred)
    pred_label = list(config.labels)[pred_idx]
    pred_score = np.round(pred[pred_idx], 6)
    
    sub = fig.add_subplot(num_rows, num_cols, k)
    sub.set_title("{} / {}\n{}".format(name, pred_label, str(pred_score)), fontsize=9)
    sub.imshow(image)
    #sub.axis("off")
    
    color = "red"
    if (pred_label == label):
        color = "lime"
            
    #sub.set_label(str(pred_score))#, fontsize=8, color=color)
    sub.axis('off')
    
    k += 1

fig.suptitle("Traffic Lights",fontsize=12)

# %%
# Write out model params to file for use in project

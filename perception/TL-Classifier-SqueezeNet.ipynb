# %% [markdown]
# # Traffic Light Classifier
# **In this notebook, a deep learning approach is used for the purposes of detecting traffic lights and their corresponding state representation (i.e. Red, Green, Yellow).**

# %%
# Dependencies
# Load pickled data
import pickle
import os
import numpy as np
import glob
import matplotlib.pyplot as plt

from math import *

# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# *Define the training and test paths...*

# %%
import model.modelconfig as config

# Define training data paths
training_path = "./data/train/images"
test_path = "./data/test/images"

# %%
# Extract number of samples

def get_samples(path, patterns = ("*.png", "*.jpg")):
    paths = []
    for key in list(config.labels.keys()):
        dir = os.path.join(path, key)
        for pattern in patterns:
            paths += glob.glob(os.path.join(dir, pattern))
    return paths

train_samples = get_samples(training_path)
test_samples = get_samples(test_path)

print("Number of training samples: {}".format(len(train_samples)))
print("Number of test samples: {}".format(len(test_samples)))
# Out:
# Number of training samples: 38868
# Number of test samples: 23135

# %%
# Uncomment to disable GPU acceleration
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
import keras;
import tensorflow as tf
import keras.backend as K

# Check keras and tensorflow versions
print("Keras version: {}".format(keras.__version__))
print("TensorFlow version: {}".format(tf.__version__))
print("Channels: {}".format(K.image_data_format()))

# Check for a GPU
if not tf.test.gpu_device_name():
    print('No GPU found. Using CPU...')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# Using TensorFlow backend.
# Keras version: 2.0.8
# TensorFlow version: 1.0.0
# Channels: channels_last
# Default GPU Device: /gpu:0

# %% [markdown]
# ### SqueezeNet model

# %%
class_labels = list(set(config.labels.values()))
print("Class labels: \n{}".format(class_labels))
# Out:
# Class labels:
# [0, 1, 2, 12]

# %%
# Model params
output_size = len(class_labels)
image_size = (None, None, 3)

dropout = 0.2
weight_decay = 1e-4

# Build model
from model.SqueezeNet import SqueezeNet

model = SqueezeNet(output_size, image_size, dropout, weight_decay)

# %% [markdown]
# #### Define Optimiser for Training

# %%
# Optimiser params
optimiser = "Adam"
loss = "categorical_crossentropy"
metrics = ["categorical_accuracy", "top_k_categorical_accuracy"]

# Compile model
model.compile(optimiser, loss, metrics=metrics, loss_weights=None, sample_weight_mode=None)

print("\n## Model ##")
print(model.summary())
# Out:
# ## Model ##
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, None, None, 96 14208       input_1[0][0]
# ____________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)          (None, None, None, 96 0           conv1[0][0]
# ____________________________________________________________________________________________________
# fire2_squeeze (Conv2D)           (None, None, None, 16 1552        maxpool1[0][0]
# ____________________________________________________________________________________________________
# fire2_expand1 (Conv2D)           (None, None, None, 64 1088        fire2_squeeze[0][0]
# ____________________________________________________________________________________________________
# fire2_expand2 (Conv2D)           (None, None, None, 64 9280        fire2_squeeze[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, None, None, 12 0           fire2_expand1[0][0]
#                                                                    fire2_expand2[0][0]
# ____________________________________________________________________________________________________
# fire3_squeeze (Conv2D)           (None, None, None, 16 2064        concatenate_1[0][0]
# ____________________________________________________________________________________________________
# fire3_expand1 (Conv2D)           (None, None, None, 64 1088        fire3_squeeze[0][0]
# ____________________________________________________________________________________________________
# fire3_expand2 (Conv2D)           (None, None, None, 64 9280        fire3_squeeze[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, None, None, 12 0           fire3_expand1[0][0]
#                                                                    fire3_expand2[0][0]
# ____________________________________________________________________________________________________
# fire4_squeeze (Conv2D)           (None, None, None, 32 4128        concatenate_2[0][0]
# ____________________________________________________________________________________________________
# fire4_expand1 (Conv2D)           (None, None, None, 12 4224        fire4_squeeze[0][0]
# ____________________________________________________________________________________________________
# fire4_expand2 (Conv2D)           (None, None, None, 12 36992       fire4_squeeze[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, None, None, 25 0           fire4_expand1[0][0]
#                                                                    fire4_expand2[0][0]
# ____________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)          (None, None, None, 25 0           concatenate_3[0][0]
# ____________________________________________________________________________________________________
# fire5_squeeze (Conv2D)           (None, None, None, 32 8224        maxpool4[0][0]
# ____________________________________________________________________________________________________
# fire5_expand1 (Conv2D)           (None, None, None, 12 4224        fire5_squeeze[0][0]
# ____________________________________________________________________________________________________
# fire5_expand2 (Conv2D)           (None, None, None, 12 36992       fire5_squeeze[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, None, None, 25 0           fire5_expand1[0][0]
#                                                                    fire5_expand2[0][0]
# ____________________________________________________________________________________________________
# fire6_squeeze (Conv2D)           (None, None, None, 48 12336       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# fire6_expand1 (Conv2D)           (None, None, None, 19 9408        fire6_squeeze[0][0]
# ____________________________________________________________________________________________________
# fire6_expand2 (Conv2D)           (None, None, None, 19 83136       fire6_squeeze[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, None, None, 38 0           fire6_expand1[0][0]
#                                                                    fire6_expand2[0][0]
# ____________________________________________________________________________________________________
# fire7_squeeze (Conv2D)           (None, None, None, 48 18480       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# fire7_expand1 (Conv2D)           (None, None, None, 19 9408        fire7_squeeze[0][0]
# ____________________________________________________________________________________________________
# fire7_expand2 (Conv2D)           (None, None, None, 19 83136       fire7_squeeze[0][0]
# ____________________________________________________________________________________________________
# concatenate_6 (Concatenate)      (None, None, None, 38 0           fire7_expand1[0][0]
#                                                                    fire7_expand2[0][0]
# ____________________________________________________________________________________________________
# fire8_squeeze (Conv2D)           (None, None, None, 64 24640       concatenate_6[0][0]
# ____________________________________________________________________________________________________
# fire8_expand1 (Conv2D)           (None, None, None, 25 16640       fire8_squeeze[0][0]
# ____________________________________________________________________________________________________
# fire8_expand2 (Conv2D)           (None, None, None, 25 147712      fire8_squeeze[0][0]
# ____________________________________________________________________________________________________
# concatenate_7 (Concatenate)      (None, None, None, 51 0           fire8_expand1[0][0]
#                                                                    fire8_expand2[0][0]
# ____________________________________________________________________________________________________
# maxpool8 (MaxPooling2D)          (None, None, None, 51 0           concatenate_7[0][0]
# ____________________________________________________________________________________________________
# fire9_squeeze (Conv2D)           (None, None, None, 64 32832       maxpool8[0][0]
# ____________________________________________________________________________________________________
# fire9_expand1 (Conv2D)           (None, None, None, 25 16640       fire9_squeeze[0][0]
# ____________________________________________________________________________________________________
# fire9_expand2 (Conv2D)           (None, None, None, 25 147712      fire9_squeeze[0][0]
# ____________________________________________________________________________________________________
# concatenate_8 (Concatenate)      (None, None, None, 51 0           fire9_expand1[0][0]
#                                                                    fire9_expand2[0][0]
# ____________________________________________________________________________________________________
# conv10 (Conv2D)                  (None, None, None, 4) 2052        concatenate_8[0][0]
# ____________________________________________________________________________________________________
# avgpool10 (GlobalAveragePooling2 (None, 4)             0           conv10[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 4)             0           avgpool10[0][0]
# ====================================================================================================
# Total params: 737,476
# Trainable params: 737,476
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# None

# %%
# Train on Bosch dataset
### Training parameters ###
noise = 0.2
batch_size = 12
max_epochs = 40

epoch_train_samples = int(floor(len(train_samples) / batch_size))
epoch_test_samples = int(floor(len(test_samples) / batch_size))

print("Steps per epoch (train): {}".format(epoch_train_samples))
print("Steps per epoch (test): {}".format(epoch_test_samples))
# Out:
# Steps per epoch (train): 3239
# Steps per epoch (test): 1927

# %% [markdown]
# ### Training

# %% [markdown]
# *Define image data generators and create noise on training set.*

# %%
import data.helpers.generator as g

print("\nInitializing generators...")

# compile and train the model using the generator function
train_generator = g.generator(training_path, config.labels, batch_size = batch_size, noise = noise)
validation_generator = g.generator(test_path, config.labels, batch_size = batch_size, noise = 0)

print(" - Done.\n")
# Out:
# Initializing generators...
#  - Done.

# %% [markdown]
# *Define callbacks for use during training.*

# %%
### Train ###
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

# setup callbacks, save every checkpoint, check for overfitting and reduce learning rate as required
callbacks = [
    CSVLogger("./model/training-loss.csv", separator=',', append = True),
    #EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience = 7),
    ModelCheckpoint(filepath = config.checkpoint_pattern.replace("*","{epoch:02d}-{val_loss:.2f}"), monitor='val_loss', save_best_only=False, save_weights_only=True, verbose=0),
]

# %% [markdown]
# #### Learning

# %%
print("\nTraining...")

epoch = 0
# Train the model using the supplied generator
history = model.fit_generator(train_generator, steps_per_epoch = epoch_train_samples, 
                              validation_data = validation_generator, validation_steps = epoch_test_samples,
                              epochs = max_epochs, callbacks = callbacks, initial_epoch = epoch)
# Out:
# Training...
# Epoch 1/40
# 3239/3239 [==============================] - 329s - loss: 0.6615 - categorical_accuracy: 0.7481 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1178 - val_categorical_accuracy: 0.6899 - val_top_k_categorical_accuracy: 0.9995
# Epoch 2/40
# 3239/3239 [==============================] - 167s - loss: 0.2024 - categorical_accuracy: 0.9437 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7758 - val_categorical_accuracy: 0.7965 - val_top_k_categorical_accuracy: 1.0000
# Epoch 3/40
# 3239/3239 [==============================] - 141s - loss: 0.1625 - categorical_accuracy: 0.9549 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9177 - val_categorical_accuracy: 0.7548 - val_top_k_categorical_accuracy: 0.9995
# Epoch 4/40
# 3239/3239 [==============================] - 141s - loss: 0.1452 - categorical_accuracy: 0.9597 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1204 - val_categorical_accuracy: 0.7861 - val_top_k_categorical_accuracy: 1.0000
# Epoch 5/40
# 3239/3239 [==============================] - 141s - loss: 0.1412 - categorical_accuracy: 0.9626 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9536 - val_categorical_accuracy: 0.7844 - val_top_k_categorical_accuracy: 0.9995
# Epoch 6/40
# 3239/3239 [==============================] - 141s - loss: 0.1305 - categorical_accuracy: 0.9633 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.6930 - val_categorical_accuracy: 0.8427 - val_top_k_categorical_accuracy: 0.9990
# Epoch 7/40
# 3239/3239 [==============================] - 141s - loss: 0.1231 - categorical_accuracy: 0.9658 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0416 - val_categorical_accuracy: 0.8075 - val_top_k_categorical_accuracy: 1.0000
# Epoch 8/40
# 3239/3239 [==============================] - 140s - loss: 0.1275 - categorical_accuracy: 0.9648 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8176 - val_categorical_accuracy: 0.8005 - val_top_k_categorical_accuracy: 0.9984
# Epoch 9/40
# 3239/3239 [==============================] - 140s - loss: 0.1261 - categorical_accuracy: 0.9651 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8127 - val_categorical_accuracy: 0.7929 - val_top_k_categorical_accuracy: 0.9984
# Epoch 10/40
# 3239/3239 [==============================] - 141s - loss: 0.1194 - categorical_accuracy: 0.9674 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0904 - val_categorical_accuracy: 0.7832 - val_top_k_categorical_accuracy: 1.0000
# Epoch 11/40
# 3239/3239 [==============================] - 141s - loss: 0.1166 - categorical_accuracy: 0.9687 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0323 - val_categorical_accuracy: 0.7976 - val_top_k_categorical_accuracy: 0.9995
# Epoch 12/40
# 3239/3239 [==============================] - 141s - loss: 0.1257 - categorical_accuracy: 0.9657 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9627 - val_categorical_accuracy: 0.8107 - val_top_k_categorical_accuracy: 0.9995
# Epoch 13/40
# 3239/3239 [==============================] - 141s - loss: 0.1124 - categorical_accuracy: 0.9692 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8199 - val_categorical_accuracy: 0.8260 - val_top_k_categorical_accuracy: 0.9990
# Epoch 14/40
# 3239/3239 [==============================] - 140s - loss: 0.1116 - categorical_accuracy: 0.9688 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0442 - val_categorical_accuracy: 0.8056 - val_top_k_categorical_accuracy: 0.9990
# Epoch 15/40
# 3239/3239 [==============================] - 140s - loss: 0.1120 - categorical_accuracy: 0.9685 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9454 - val_categorical_accuracy: 0.8113 - val_top_k_categorical_accuracy: 0.9995
# Epoch 16/40
# 3239/3239 [==============================] - 141s - loss: 0.1079 - categorical_accuracy: 0.9714 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8589 - val_categorical_accuracy: 0.8258 - val_top_k_categorical_accuracy: 1.0000
# Epoch 17/40
# 3239/3239 [==============================] - 141s - loss: 0.1098 - categorical_accuracy: 0.9706 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9394 - val_categorical_accuracy: 0.8031 - val_top_k_categorical_accuracy: 0.9990
# Epoch 18/40
# 3239/3239 [==============================] - 141s - loss: 0.0988 - categorical_accuracy: 0.9726 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0697 - val_categorical_accuracy: 0.7850 - val_top_k_categorical_accuracy: 0.9995
# Epoch 19/40
# 3239/3239 [==============================] - 141s - loss: 0.1005 - categorical_accuracy: 0.9712 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7551 - val_categorical_accuracy: 0.8380 - val_top_k_categorical_accuracy: 1.0000
# Epoch 20/40
# 3239/3239 [==============================] - 140s - loss: 0.0992 - categorical_accuracy: 0.9714 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9608 - val_categorical_accuracy: 0.8218 - val_top_k_categorical_accuracy: 0.9995
# Epoch 21/40
# 3239/3239 [==============================] - 140s - loss: 0.1035 - categorical_accuracy: 0.9705 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7494 - val_categorical_accuracy: 0.8154 - val_top_k_categorical_accuracy: 1.0000
# Epoch 22/40
# 3239/3239 [==============================] - 140s - loss: 0.0921 - categorical_accuracy: 0.9731 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1256 - val_categorical_accuracy: 0.7867 - val_top_k_categorical_accuracy: 0.9995
# Epoch 23/40
# 3239/3239 [==============================] - 141s - loss: 0.1084 - categorical_accuracy: 0.9689 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1669 - val_categorical_accuracy: 0.7940 - val_top_k_categorical_accuracy: 0.9995
# Epoch 24/40
# 3239/3239 [==============================] - 141s - loss: 0.1284 - categorical_accuracy: 0.9652 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1199 - val_categorical_accuracy: 0.8107 - val_top_k_categorical_accuracy: 1.0000
# Epoch 25/40
# 3239/3239 [==============================] - 141s - loss: 0.1076 - categorical_accuracy: 0.9702 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7708 - val_categorical_accuracy: 0.8221 - val_top_k_categorical_accuracy: 0.9984
# Epoch 26/40
# 3239/3239 [==============================] - 140s - loss: 0.1209 - categorical_accuracy: 0.9681 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8951 - val_categorical_accuracy: 0.7943 - val_top_k_categorical_accuracy: 0.9995
# Epoch 27/40
# 3239/3239 [==============================] - 141s - loss: 0.1076 - categorical_accuracy: 0.9704 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9302 - val_categorical_accuracy: 0.8061 - val_top_k_categorical_accuracy: 1.0000
# Epoch 28/40
# 3239/3239 [==============================] - 140s - loss: 0.1204 - categorical_accuracy: 0.9664 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0101 - val_categorical_accuracy: 0.7730 - val_top_k_categorical_accuracy: 0.9995
# Epoch 29/40
# 3239/3239 [==============================] - 140s - loss: 0.1095 - categorical_accuracy: 0.9689 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0381 - val_categorical_accuracy: 0.8056 - val_top_k_categorical_accuracy: 0.9990
# Epoch 30/40
# 3239/3239 [==============================] - 140s - loss: 0.1128 - categorical_accuracy: 0.9686 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0377 - val_categorical_accuracy: 0.7880 - val_top_k_categorical_accuracy: 1.0000
# Epoch 31/40
# 3239/3239 [==============================] - 140s - loss: 0.1120 - categorical_accuracy: 0.9668 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1675 - val_categorical_accuracy: 0.7639 - val_top_k_categorical_accuracy: 0.9995
# Epoch 32/40
# 3239/3239 [==============================] - 140s - loss: 0.1313 - categorical_accuracy: 0.9652 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0640 - val_categorical_accuracy: 0.7879 - val_top_k_categorical_accuracy: 0.9979
# Epoch 33/40
# 3239/3239 [==============================] - 140s - loss: 0.1053 - categorical_accuracy: 0.9712 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1145 - val_categorical_accuracy: 0.7842 - val_top_k_categorical_accuracy: 0.9984
# Epoch 34/40
# 3239/3239 [==============================] - 140s - loss: 0.1157 - categorical_accuracy: 0.9675 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9365 - val_categorical_accuracy: 0.7732 - val_top_k_categorical_accuracy: 0.9995
# Epoch 35/40
# 3239/3239 [==============================] - 140s - loss: 0.1203 - categorical_accuracy: 0.9667 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1872 - val_categorical_accuracy: 0.7724 - val_top_k_categorical_accuracy: 0.9984
# Epoch 36/40
# 3239/3239 [==============================] - 140s - loss: 0.1139 - categorical_accuracy: 0.9690 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7843 - val_categorical_accuracy: 0.8090 - val_top_k_categorical_accuracy: 1.0000
# Epoch 37/40
# 3239/3239 [==============================] - 140s - loss: 0.1151 - categorical_accuracy: 0.9690 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.8452 - val_categorical_accuracy: 0.7959 - val_top_k_categorical_accuracy: 0.9995
# Epoch 38/40
# 3239/3239 [==============================] - 139s - loss: 0.1065 - categorical_accuracy: 0.9697 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.0154 - val_categorical_accuracy: 0.8046 - val_top_k_categorical_accuracy: 0.9995
# Epoch 39/40
# 3239/3239 [==============================] - 140s - loss: 0.1201 - categorical_accuracy: 0.9677 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.7907 - val_categorical_accuracy: 0.8332 - val_top_k_categorical_accuracy: 0.9995
# Epoch 40/40
# 3239/3239 [==============================] - 140s - loss: 0.1015 - categorical_accuracy: 0.9730 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.9895 - val_categorical_accuracy: 0.7839 - val_top_k_categorical_accuracy: 0.9995

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_categorical_accuracy', 'loss', 'categorical_accuracy', 'top_k_categorical_accuracy', 'val_loss', 'val_top_k_categorical_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
valid_path = "./data/valid/images"

# %%
from mpl_toolkits.axes_grid1 import ImageGrid
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg

images = []
labels = []
labelnames = []

for dir in os.listdir(valid_path):
    sub_path = os.path.join(valid_path, dir)
    if (os.path.isdir(sub_path) and dir in config.labels):
        for img_name in os.listdir(sub_path):
            img_path = os.path.join(sub_path, img_name)
            images.append(img_path)
            labels.append(config.labels[dir])
            labelnames.append(dir)

num_rows = 6
num_cols = 4

fig = plt.figure(figsize=(18, 16))  # width, height in inches

k = 1

for i in range(len(labels)):
    image = mpimg.imread(images[i])
    label = labels[i]
    name = labelnames[i]
    
    image = np.asarray(image)
    
    pred = model.predict(image[None, :, :, 0:3], batch_size=1)[0]
    
    pred_idx = np.argmax(pred)
    pred_label = list(config.labels)[pred_idx]
    pred_score = np.round(pred[pred_idx], 6)
    
    sub = fig.add_subplot(num_rows, num_cols, k)
    sub.set_title("{} / {}\n{}".format(name, pred_label, str(pred_score)), fontsize=9)
    sub.imshow(image)
    #sub.axis("off")
    
    color = "red"
    if (pred_label == label):
        color = "lime"
            
    #sub.set_label(str(pred_score))#, fontsize=8, color=color)
    sub.axis('off')
    
    k += 1

fig.suptitle("Traffic Lights",fontsize=12)

# %%
# Write out model params to file for use in project

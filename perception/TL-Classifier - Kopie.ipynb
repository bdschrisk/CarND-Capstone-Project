# %% [markdown]
# # Traffic Light Classifier
# **In this notebook, a deep learning approach is used for the purposes of detecting traffic lights and their corresponding state representation (i.e. Red, Green, Yellow).**

# %%
# Dependencies
# Load pickled data
import pickle
import os
import numpy as np
import glob
import matplotlib.pyplot as plt

from math import *

# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# *Define the training and test paths...*

# %%
# Define training data paths
training_path = "./data/train/images"
test_path = "./data/test/images"

# %%
# Extract number of samples
pattern1 = "**/*.png"
pattern2 = "**/*.jpg"

train_samples = glob.glob(os.path.join(training_path, pattern1)) + glob.glob(os.path.join(training_path, pattern2))
test_samples = glob.glob(os.path.join(test_path, pattern1)) + glob.glob(os.path.join(test_path, pattern2))

print("Number of training samples: {}".format(len(train_samples)))
print("Number of test samples: {}".format(len(test_samples)))
# Out:
# Number of training samples: 39956
# Number of test samples: 23940

# %%
# Uncomment to disable GPU acceleration
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
import keras;
import tensorflow as tf
import keras.backend as K

# Check keras and tensorflow versions
print("Keras version: {}".format(keras.__version__))
print("TensorFlow version: {}".format(tf.__version__))
print("Channels: {}".format(K.image_data_format()))

# Check for a GPU
if not tf.test.gpu_device_name():
    print('No GPU found. Using CPU...')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# Using TensorFlow backend.
# Keras version: 2.0.8
# TensorFlow version: 1.0.0
# Channels: channels_last
# Default GPU Device: /gpu:0

# %% [markdown]
# ### DenseNet model

# %%
import model.modelconfig as config

class_labels = list(set(config.labels.values()))
print("Class labels: \n{}".format(class_labels))
# Out:
# Class labels:
# [0, 1, 34, 2, 36, 10, 42, 12, 44, 17, 18, 20, 26, 28]

# %%
# Model params
output_size = len(class_labels)
image_size = (None, None, 3)

depth = 25 #40
dense_blocks = 3 #3
growth_rate = 12 #12
filters = 16

dropout = 0
weight_decay = 1e-4

# Build model
from model.DenseNet import DenseNet

densenet = DenseNet(output_size, image_size, depth, dense_blocks, growth_rate, 
                 filters, dropout_rate=dropout, weight_decay=weight_decay)
model = densenet.model

# %% [markdown]
# #### Define Optimiser for Training

# %%
# Optimiser params
optimiser = "Adam"
loss = "categorical_crossentropy"
metrics = ["categorical_accuracy", "top_k_categorical_accuracy"]

# Compile model
model.compile(optimiser, loss, metrics=metrics, loss_weights=None, sample_weight_mode=None)

print("\n## Model ##")
print(model.summary())
# Out:
# ## Model ##
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# normalizer_1 (Normalizer)        (None, None, None, 3) 0           input_1[0][0]
# ____________________________________________________________________________________________________
# initial_conv2D (Conv2D)          (None, None, None, 16 432         normalizer_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, None, None, 16 64          initial_conv2D[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, None, None, 16 0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, None, None, 12 1728        activation_1[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, None, None, 28 0           initial_conv2D[0][0]
#                                                                    conv2d_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, None, None, 28 112         concatenate_1[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, None, None, 28 0           batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, None, None, 12 3024        activation_2[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, None, None, 40 0           initial_conv2D[0][0]
#                                                                    conv2d_1[0][0]
#                                                                    conv2d_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, None, None, 40 160         concatenate_2[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, None, None, 40 0           batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, None, None, 12 4320        activation_3[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, None, None, 52 0           initial_conv2D[0][0]
#                                                                    conv2d_1[0][0]
#                                                                    conv2d_2[0][0]
#                                                                    conv2d_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, None, None, 52 208         concatenate_3[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, None, None, 52 0           batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, None, None, 12 5616        activation_4[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, None, None, 64 0           initial_conv2D[0][0]
#                                                                    conv2d_1[0][0]
#                                                                    conv2d_2[0][0]
#                                                                    conv2d_3[0][0]
#                                                                    conv2d_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, None, None, 64 256         concatenate_4[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, None, None, 64 0           batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, None, None, 12 6912        activation_5[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, None, None, 76 0           initial_conv2D[0][0]
#                                                                    conv2d_1[0][0]
#                                                                    conv2d_2[0][0]
#                                                                    conv2d_3[0][0]
#                                                                    conv2d_4[0][0]
#                                                                    conv2d_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, None, None, 76 304         concatenate_5[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, None, None, 76 0           batch_normalization_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, None, None, 12 8208        activation_6[0][0]
# ____________________________________________________________________________________________________
# concatenate_6 (Concatenate)      (None, None, None, 88 0           initial_conv2D[0][0]
#                                                                    conv2d_1[0][0]
#                                                                    conv2d_2[0][0]
#                                                                    conv2d_3[0][0]
#                                                                    conv2d_4[0][0]
#                                                                    conv2d_5[0][0]
#                                                                    conv2d_6[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNorm (None, None, None, 88 352         concatenate_6[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, None, None, 88 0           batch_normalization_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, None, None, 12 9504        activation_7[0][0]
# ____________________________________________________________________________________________________
# concatenate_7 (Concatenate)      (None, None, None, 10 0           initial_conv2D[0][0]
#                                                                    conv2d_1[0][0]
#                                                                    conv2d_2[0][0]
#                                                                    conv2d_3[0][0]
#                                                                    conv2d_4[0][0]
#                                                                    conv2d_5[0][0]
#                                                                    conv2d_6[0][0]
#                                                                    conv2d_7[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNorm (None, None, None, 10 400         concatenate_7[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, None, None, 10 0           batch_normalization_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, None, None, 10 10000       activation_8[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_1 (AveragePool (None, None, None, 10 0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, None, None, 10 400         average_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, None, None, 10 0           batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, None, None, 12 10800       activation_9[0][0]
# ____________________________________________________________________________________________________
# concatenate_8 (Concatenate)      (None, None, None, 11 0           average_pooling2d_1[0][0]
#                                                                    conv2d_9[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None, None, None, 11 448         concatenate_8[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, None, None, 11 0           batch_normalization_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, None, None, 12 12096       activation_10[0][0]
# ____________________________________________________________________________________________________
# concatenate_9 (Concatenate)      (None, None, None, 12 0           average_pooling2d_1[0][0]
#                                                                    conv2d_9[0][0]
#                                                                    conv2d_10[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11 (BatchNor (None, None, None, 12 496         concatenate_9[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, None, None, 12 0           batch_normalization_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, None, None, 12 13392       activation_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_10 (Concatenate)     (None, None, None, 13 0           average_pooling2d_1[0][0]
#                                                                    conv2d_9[0][0]
#                                                                    conv2d_10[0][0]
#                                                                    conv2d_11[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_12 (BatchNor (None, None, None, 13 544         concatenate_10[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, None, None, 13 0           batch_normalization_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, None, None, 12 14688       activation_12[0][0]
# ____________________________________________________________________________________________________
# concatenate_11 (Concatenate)     (None, None, None, 14 0           average_pooling2d_1[0][0]
#                                                                    conv2d_9[0][0]
#                                                                    conv2d_10[0][0]
#                                                                    conv2d_11[0][0]
#                                                                    conv2d_12[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_13 (BatchNor (None, None, None, 14 592         concatenate_11[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, None, None, 14 0           batch_normalization_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, None, None, 12 15984       activation_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_12 (Concatenate)     (None, None, None, 16 0           average_pooling2d_1[0][0]
#                                                                    conv2d_9[0][0]
#                                                                    conv2d_10[0][0]
#                                                                    conv2d_11[0][0]
#                                                                    conv2d_12[0][0]
#                                                                    conv2d_13[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_14 (BatchNor (None, None, None, 16 640         concatenate_12[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, None, None, 16 0           batch_normalization_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, None, None, 12 17280       activation_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_13 (Concatenate)     (None, None, None, 17 0           average_pooling2d_1[0][0]
#                                                                    conv2d_9[0][0]
#                                                                    conv2d_10[0][0]
#                                                                    conv2d_11[0][0]
#                                                                    conv2d_12[0][0]
#                                                                    conv2d_13[0][0]
#                                                                    conv2d_14[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_15 (BatchNor (None, None, None, 17 688         concatenate_13[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, None, None, 17 0           batch_normalization_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, None, None, 12 18576       activation_15[0][0]
# ____________________________________________________________________________________________________
# concatenate_14 (Concatenate)     (None, None, None, 18 0           average_pooling2d_1[0][0]
#                                                                    conv2d_9[0][0]
#                                                                    conv2d_10[0][0]
#                                                                    conv2d_11[0][0]
#                                                                    conv2d_12[0][0]
#                                                                    conv2d_13[0][0]
#                                                                    conv2d_14[0][0]
#                                                                    conv2d_15[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_16 (BatchNor (None, None, None, 18 736         concatenate_14[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, None, None, 18 0           batch_normalization_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, None, None, 18 33856       activation_16[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_2 (AveragePool (None, None, None, 18 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_17 (BatchNor (None, None, None, 18 736         average_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, None, None, 18 0           batch_normalization_17[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, None, None, 12 19872       activation_17[0][0]
# ____________________________________________________________________________________________________
# concatenate_15 (Concatenate)     (None, None, None, 19 0           average_pooling2d_2[0][0]
#                                                                    conv2d_17[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_18 (BatchNor (None, None, None, 19 784         concatenate_15[0][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, None, None, 19 0           batch_normalization_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, None, None, 12 21168       activation_18[0][0]
# ____________________________________________________________________________________________________
# concatenate_16 (Concatenate)     (None, None, None, 20 0           average_pooling2d_2[0][0]
#                                                                    conv2d_17[0][0]
#                                                                    conv2d_18[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_19 (BatchNor (None, None, None, 20 832         concatenate_16[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, None, None, 20 0           batch_normalization_19[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, None, None, 12 22464       activation_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_17 (Concatenate)     (None, None, None, 22 0           average_pooling2d_2[0][0]
#                                                                    conv2d_17[0][0]
#                                                                    conv2d_18[0][0]
#                                                                    conv2d_19[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_20 (BatchNor (None, None, None, 22 880         concatenate_17[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, None, None, 22 0           batch_normalization_20[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, None, None, 12 23760       activation_20[0][0]
# ____________________________________________________________________________________________________
# concatenate_18 (Concatenate)     (None, None, None, 23 0           average_pooling2d_2[0][0]
#                                                                    conv2d_17[0][0]
#                                                                    conv2d_18[0][0]
#                                                                    conv2d_19[0][0]
#                                                                    conv2d_20[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_21 (BatchNor (None, None, None, 23 928         concatenate_18[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, None, None, 23 0           batch_normalization_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, None, None, 12 25056       activation_21[0][0]
# ____________________________________________________________________________________________________
# concatenate_19 (Concatenate)     (None, None, None, 24 0           average_pooling2d_2[0][0]
#                                                                    conv2d_17[0][0]
#                                                                    conv2d_18[0][0]
#                                                                    conv2d_19[0][0]
#                                                                    conv2d_20[0][0]
#                                                                    conv2d_21[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_22 (BatchNor (None, None, None, 24 976         concatenate_19[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, None, None, 24 0           batch_normalization_22[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, None, None, 12 26352       activation_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_20 (Concatenate)     (None, None, None, 25 0           average_pooling2d_2[0][0]
#                                                                    conv2d_17[0][0]
#                                                                    conv2d_18[0][0]
#                                                                    conv2d_19[0][0]
#                                                                    conv2d_20[0][0]
#                                                                    conv2d_21[0][0]
#                                                                    conv2d_22[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_23 (BatchNor (None, None, None, 25 1024        concatenate_20[0][0]
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, None, None, 25 0           batch_normalization_23[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, None, None, 12 27648       activation_23[0][0]
# ____________________________________________________________________________________________________
# concatenate_21 (Concatenate)     (None, None, None, 26 0           average_pooling2d_2[0][0]
#                                                                    conv2d_17[0][0]
#                                                                    conv2d_18[0][0]
#                                                                    conv2d_19[0][0]
#                                                                    conv2d_20[0][0]
#                                                                    conv2d_21[0][0]
#                                                                    conv2d_22[0][0]
#                                                                    conv2d_23[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_24 (BatchNor (None, None, None, 26 1072        concatenate_21[0][0]
# ____________________________________________________________________________________________________
# activation_24 (Activation)       (None, None, None, 26 0           batch_normalization_24[0][0]
# ____________________________________________________________________________________________________
# global_average_pooling2d_1 (Glob (None, 268)           0           activation_24[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 14)            3766        global_average_pooling2d_1[0][0]
# ====================================================================================================
# Total params: 370,134
# Trainable params: 363,318
# Non-trainable params: 6,816
# ____________________________________________________________________________________________________
# None

# %%
# Train on Bosch dataset
### Training parameters ###
noise = 0.0
batch_size = 32
max_epochs = 40

epoch_train_samples = int(floor(len(train_samples) / batch_size))
epoch_test_samples = int(floor(len(test_samples) / batch_size))

print("Steps per epoch (train): {}".format(epoch_train_samples))
print("Steps per epoch (test): {}".format(epoch_test_samples))
# Out:
# Steps per epoch (train): 2497
# Steps per epoch (test): 1496

# %% [markdown]
# ### Training

# %% [markdown]
# *Define image data generators and create noise on training set.*

# %%
import data.helpers.generator as g

print("\nInitializing generators...")

# compile and train the model using the generator function
train_generator = g.generator(training_path, config.labels, batch_size = batch_size, noise = noise)
validation_generator = g.generator(test_path, config.labels, batch_size = batch_size, noise = 0)

print(" - Done.\n")
# Out:
# Initializing generators...
#  - Done.

# %% [markdown]
# *Define callbacks for use during training.*

# %%
### Train ###
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint

# setup callbacks, save every checkpoint, check for overfitting and reduce learning rate as required
callbacks = [
    CSVLogger("./model/training-loss.csv", separator=',', append = True),
    EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience = 10),
    ModelCheckpoint(filepath = config.checkpoint_pattern.replace("*","{epoch:02d}-{val_loss:.2f}"), monitor='val_loss', save_best_only=False, save_weights_only=True, verbose=0),
]

# %% [markdown]
# #### Learning

# %%
print("\nTraining...")

epoch = 14
# Train the model using the supplied generator
history = model.fit_generator(train_generator, steps_per_epoch = epoch_train_samples, 
                              validation_data = validation_generator, validation_steps = epoch_test_samples,
                              epochs = max_epochs, callbacks = callbacks, initial_epoch = epoch)
# Out:
# Training...
# Epoch 15/40
# 2497/2497 [==============================] - 1327s - loss: 0.0946 - categorical_accuracy: 0.9768 - top_k_categorical_accuracy: 0.9997 - val_loss: 1.3811 - val_categorical_accuracy: 0.7343 - val_top_k_categorical_accuracy: 0.9895
# Epoch 16/40
# 2497/2497 [==============================] - 1328s - loss: 0.0919 - categorical_accuracy: 0.9781 - top_k_categorical_accuracy: 0.9997 - val_loss: 1.2459 - val_categorical_accuracy: 0.7719 - val_top_k_categorical_accuracy: 0.9788
# Epoch 17/40
# 2497/2497 [==============================] - 1330s - loss: 0.0936 - categorical_accuracy: 0.9777 - top_k_categorical_accuracy: 0.9995 - val_loss: 1.2861 - val_categorical_accuracy: 0.7527 - val_top_k_categorical_accuracy: 0.9745
# Epoch 18/40
# 2497/2497 [==============================] - 1330s - loss: 0.0873 - categorical_accuracy: 0.9790 - top_k_categorical_accuracy: 0.9997 - val_loss: 1.3590 - val_categorical_accuracy: 0.7209 - val_top_k_categorical_accuracy: 0.9145
# Epoch 19/40
# 2497/2497 [==============================] - 1324s - loss: 0.0825 - categorical_accuracy: 0.9806 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.3247 - val_categorical_accuracy: 0.6783 - val_top_k_categorical_accuracy: 0.9540
# Epoch 20/40
# 2497/2497 [==============================] - 1320s - loss: 0.0829 - categorical_accuracy: 0.9807 - top_k_categorical_accuracy: 0.9997 - val_loss: 1.6499 - val_categorical_accuracy: 0.7359 - val_top_k_categorical_accuracy: 0.9437
# Epoch 21/40
# 2497/2497 [==============================] - 1312s - loss: 0.0811 - categorical_accuracy: 0.9803 - top_k_categorical_accuracy: 0.9997 - val_loss: 1.8014 - val_categorical_accuracy: 0.6827 - val_top_k_categorical_accuracy: 0.9363
# Epoch 22/40
# 2497/2497 [==============================] - 1306s - loss: 0.0770 - categorical_accuracy: 0.9812 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.2938 - val_categorical_accuracy: 0.7568 - val_top_k_categorical_accuracy: 0.9417
# Epoch 23/40
# 2497/2497 [==============================] - 1309s - loss: 0.0736 - categorical_accuracy: 0.9825 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.0991 - val_categorical_accuracy: 0.7387 - val_top_k_categorical_accuracy: 0.9872
# Epoch 24/40
# 2497/2497 [==============================] - 1312s - loss: 0.0728 - categorical_accuracy: 0.9840 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.1894 - val_categorical_accuracy: 0.7748 - val_top_k_categorical_accuracy: 0.9590
# Epoch 25/40
# 2497/2497 [==============================] - 1308s - loss: 0.0734 - categorical_accuracy: 0.9825 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.4336 - val_categorical_accuracy: 0.7196 - val_top_k_categorical_accuracy: 0.9625
# Epoch 26/40
# 2497/2497 [==============================] - 1316s - loss: 0.0691 - categorical_accuracy: 0.9844 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.0809 - val_categorical_accuracy: 0.7982 - val_top_k_categorical_accuracy: 0.9776
# Epoch 27/40
# 2497/2497 [==============================] - 1316s - loss: 0.0730 - categorical_accuracy: 0.9832 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.5225 - val_categorical_accuracy: 0.7568 - val_top_k_categorical_accuracy: 0.9814
# Epoch 28/40
# 2497/2497 [==============================] - 1310s - loss: 0.0685 - categorical_accuracy: 0.9842 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.1836 - val_categorical_accuracy: 0.7866 - val_top_k_categorical_accuracy: 0.9679
# Epoch 29/40
# 2497/2497 [==============================] - 1312s - loss: 0.0668 - categorical_accuracy: 0.9855 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.4692 - val_categorical_accuracy: 0.6910 - val_top_k_categorical_accuracy: 0.9701
# Epoch 30/40
# 2497/2497 [==============================] - 1315s - loss: 0.0654 - categorical_accuracy: 0.9855 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.6740 - val_categorical_accuracy: 0.7333 - val_top_k_categorical_accuracy: 0.9905
# Epoch 31/40
# 2497/2497 [==============================] - 1315s - loss: 0.0648 - categorical_accuracy: 0.9854 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.4227 - val_categorical_accuracy: 0.7648 - val_top_k_categorical_accuracy: 0.9510
# Epoch 32/40
# 2497/2497 [==============================] - 1319s - loss: 0.0634 - categorical_accuracy: 0.9858 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.1011 - val_categorical_accuracy: 0.8045 - val_top_k_categorical_accuracy: 0.9750
# Epoch 33/40
# 2497/2497 [==============================] - 1301s - loss: 0.0622 - categorical_accuracy: 0.9860 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.3475 - val_categorical_accuracy: 0.7564 - val_top_k_categorical_accuracy: 0.9554
# Epoch 34/40
# 2497/2497 [==============================] - 1304s - loss: 0.0620 - categorical_accuracy: 0.9868 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.3276 - val_categorical_accuracy: 0.7238 - val_top_k_categorical_accuracy: 0.9826
# Epoch 35/40
# 2497/2497 [==============================] - 1309s - loss: 0.0612 - categorical_accuracy: 0.9865 - top_k_categorical_accuracy: 0.9998 - val_loss: 1.9188 - val_categorical_accuracy: 0.7211 - val_top_k_categorical_accuracy: 0.9472
# Epoch 36/40
# 2497/2497 [==============================] - 1313s - loss: 0.0590 - categorical_accuracy: 0.9871 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.3877 - val_categorical_accuracy: 0.7351 - val_top_k_categorical_accuracy: 0.9669
# Epoch 37/40
# 2497/2497 [==============================] - 1304s - loss: 0.0584 - categorical_accuracy: 0.9878 - top_k_categorical_accuracy: 0.9999 - val_loss: 1.1530 - val_categorical_accuracy: 0.7336 - val_top_k_categorical_accuracy: 0.9845

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_top_k_categorical_accuracy', 'val_loss', 'categorical_accuracy', 'top_k_categorical_accuracy', 'val_categorical_accuracy', 'loss'])

# %%
# TODO plot history
#plt.figure(1)
# summarize history for accuracy
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
valid_path = "./data/valid/images"

# %%
from mpl_toolkits.axes_grid1 import ImageGrid
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg

images = []
labels = []
labelnames = []

for dir in os.listdir(valid_path):
    sub_path = os.path.join(valid_path, dir)
    if (os.path.isdir(sub_path) and dir in config.labels):
        for img_name in os.listdir(sub_path):
            img_path = os.path.join(sub_path, img_name)
            images.append(img_path)
            labels.append(config.labels[dir])
            labelnames.append(dir)

num_rows = 6
num_cols = 4

fig = plt.figure(figsize=(18, 16))  # width, height in inches

k = 1

for i in range(len(labels)):
    image = mpimg.imread(images[i])
    label = labels[i]
    name = labelnames[i]
    
    image = np.asarray(image)
    
    pred = model.predict(image[None, :, :, 0:3], batch_size=1)[0]
    
    pred_idx = np.argmax(pred)
    pred_label = list(config.labels)[pred_idx]
    pred_score = np.round(pred[pred_idx], 6)
    
    sub = fig.add_subplot(num_rows, num_cols, k)
    sub.set_title("{} / {}\n{}".format(name, pred_label, str(pred_score)), fontsize=9)
    sub.imshow(image)
    #sub.axis("off")
    
    color = "red"
    if (pred_label == label):
        color = "lime"
            
    #sub.set_label(str(pred_score))#, fontsize=8, color=color)
    sub.axis('off')
    
    k += 1

fig.suptitle("Traffic Lights",fontsize=12)

# %%
# Write out model params to file for use in project
